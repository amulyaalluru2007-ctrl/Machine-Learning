# %%
import sys
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import seaborn as sns

# %%
print("Library Versions")
print("-" * 40)
print(f"Pandas         : {pd.__version__}")
print(f"NumPy          : {np.__version__}")
print(f"Scikit-learn   : {sklearn.__version__}")
print(f"Matplotlib     : {matplotlib.__version__}")
print(f"Seaborn        : {sns.__version__}")
# Out:
# Library Versions
# ----------------------------------------
# Pandas         : 2.2.2
# NumPy          : 2.0.2
# Scikit-learn   : 1.6.1
# Matplotlib     : 3.10.0
# Seaborn        : 0.13.2

# %%
import pandas as pd
import seaborn as sns

# %%
from pandas import read_csv
df=read_csv('train-selected-columns.csv')

# %%
df.head(5)
# Out:
#    Student_ID  Age  Gender  Degree Branch  CGPA  Internships  Projects  \
# 0        1048   22  Female  B.Tech    ECE  6.29            0         3
# 1       37820   20  Female     BCA    ECE  6.05            1         4
# 2       49668   22    Male     MCA     ME  7.22            1         4
# 3       19467   22    Male     MCA     ME  7.78            2         4
# 4       23094   20  Female  B.Tech     ME  7.63            1         4
#
#    Coding_Skills  Communication_Skills
# 0              4                     6
# 1              6                     8
# 2              6                     6
# 3              6                     6
# 4              6                     5

# %%
df.tail(5)
# Out:
#        Student_ID  Age  Gender  Degree Branch  CGPA  Internships  Projects  \
# 44995        9362   20    Male     MCA  Civil  7.84            2         5
# 44996        8940   19  Female    B.Sc     ME  8.28            1         4
# 44997       13097   20  Female    B.Sc  Civil  8.88            0         4
# 44998       12958   24  Female     MCA    ECE  5.90            1         3
# 44999        9565   23  Female  B.Tech     ME  6.28            0         4
#
#        Coding_Skills  Communication_Skills
# 44995              9                     7
# 44996              6                     5
# 44997              4                     5
# 44998              6                     6
# 44999              6                     6

# %%
df.shape
# Out:
# (45000, 10)

# %%
rows,columns=df.shape
rows
# Out:
# 45000

# %%
rows,columns=df.shape
columns
# Out:
# 10

# %%
df['Age']
# Out:
# 0        22
# 1        20
# 2        22
# 3        22
# 4        20
#          ..
# 44995    20
# 44996    19
# 44997    20
# 44998    24
# 44999    23
# Name: Age, Length: 45000, dtype: int64

# %%
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'Degree', 'Branch', 'CGPA',
#        'Internships', 'Projects', 'Coding_Skills', 'Communication_Skills'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Student_ID                int64
# Age                       int64
# Gender                   object
# Degree                   object
# Branch                   object
# CGPA                    float64
# Internships               int64
# Projects                  int64
# Coding_Skills             int64
# Communication_Skills      int64
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# int64      6
# object     3
# float64    1
# Name: count, dtype: int64

# %%
missing_data = pd.DataFrame({
    "Missing Values": df.isnull().sum(),
    "Percentage": (df.isnull().sum()/len(df))*100
})

missing_data
# Out:
#                       Missing Values  Percentage
# Student_ID                         0         0.0
# Age                                0         0.0
# Gender                             0         0.0
# Degree                             0         0.0
# Branch                             0         0.0
# CGPA                               0         0.0
# Internships                        0         0.0
# Projects                           0         0.0
# Coding_Skills                      0         0.0
# Communication_Skills               0         0.0

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
# cbar=False hides the color bar; yticklabels=False hides row numbers for cleaner v
sns.heatmap(df.isnull(), cbar=False, yticklabels=False, cmap="viridis")
plt.title("missing")
plt.show()

# %%
duplicate_rows = df[df.duplicated()]
print(f"Total duplicate rows detected: {len(duplicate_rows)}")
print(duplicate_rows)
print("-" * 40)
# Out:
# Total duplicate rows detected: 0
# Empty DataFrame
# Columns: [Student_ID, Age, Gender, Degree, Branch, CGPA, Internships, Projects, Coding_Skills, Communication_Skills]
# Index: []
# ----------------------------------------

# %%
df[df['Age'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Student_ID, Age, Gender, Degree, Branch, CGPA, Internships, Projects, Coding_Skills, Communication_Skills]
# Index: []

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (45000, 10)

# %%
df.describe()
# Out:
#          Student_ID           Age          CGPA   Internships      Projects  \
# count  45000.000000  45000.000000  45000.000000  45000.000000  45000.000000
# mean   24977.962600     20.999333      7.002290      0.774089      3.734222
# std    14425.605704      1.995071      0.993855      0.844750      0.923738
# min        1.000000     18.000000      4.500000      0.000000      1.000000
# 25%    12509.750000     19.000000      6.320000      0.000000      3.000000
# 50%    24957.500000     21.000000      7.000000      1.000000      4.000000
# 75%    37475.250000     23.000000      7.670000      1.000000      4.000000
# max    50000.000000     24.000000      9.800000      3.000000      6.000000
#
#        Coding_Skills  Communication_Skills
# count   45000.000000          45000.000000
# mean        5.691800              5.501644
# std         1.994674              1.515374
# min         1.000000              1.000000
# 25%         4.000000              4.000000
# ...

# %%
df["CGPA"].value_counts()
# Out:
# CGPA
# 4.50    271
# 6.90    207
# 6.57    201
# 7.30    198
# 6.92    198
#        ...
# 9.78      3
# 9.77      3
# 9.58      2
# 9.65      2
# 9.73      1
# Name: count, Length: 531, dtype: int64

# %%
(df["CGPA"].value_counts(normalize=True) * 100).round(2)
# Out:
# CGPA
# 4.50    0.60
# 6.90    0.46
# 6.57    0.45
# 7.30    0.44
# 6.92    0.44
#         ...
# 9.78    0.01
# 9.77    0.01
# 9.58    0.00
# 9.65    0.00
# 9.73    0.00
# Name: proportion, Length: 531, dtype: float64
